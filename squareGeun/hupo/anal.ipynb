# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import utill

utill.set_os_specific_font()
# Out:
# 운영체제: Darwin, 폰트 설정 완료: AppleGothic

# %%
hupoDF = pd.read_csv('hupo.csv').drop(columns='Unnamed: 0')
# sns.set_style('white')
# plt.figure(figsize=(10,20))
# sns.lmplot(data=hupoDF,x='water_avg_temp',y='precipitation(mm)')
# plt.xticks(range(0,30))
# sns.lmplot(data=hupoDF,x='hupo_avg_temp',y='precipitation(mm)')
# plt.xticks(range(0,30),rotation=90)
# plt.yticks(range(0,400,100))

# %%
for month in range(1,13):
    mask = hupoDF['month'] == month
    monthByrain_temp_corr = hupoDF.loc[mask,['year','water_avg_temp','precipitation(mm)']]
    sns.lmplot(data=monthByrain_temp_corr,x='water_avg_temp',y='precipitation(mm)',hue='year')

# %%
hupoDF[['water_avg_temp','hupo_avg_temp','precipitation(mm)']].corr()
# Out:
#                    water_avg_temp  hupo_avg_temp  precipitation(mm)
# water_avg_temp           1.000000       0.854354           0.571354
# hupo_avg_temp            0.854354       1.000000           0.474969
# precipitation(mm)        0.571354       0.474969           1.000000
